# %%
# %pip install gradio opencv-python torch torchvision numpy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gradio in c:\users\dell\appdata\roaming\python\python312\site-packages (6.1.0)
# Requirement already satisfied: opencv-python in c:\users\dell\appdata\roaming\python\python312\site-packages (4.12.0.88)
# Requirement already satisfied: torch in c:\users\dell\appdata\roaming\python\python312\site-packages (2.9.1)
# Requirement already satisfied: torchvision in c:\users\dell\appdata\roaming\python\python312\site-packages (0.24.1)
# Requirement already satisfied: numpy in c:\users\dell\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\roaming\python\python312\site-packages (3.10.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (4.8.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.124.4)
# Requirement already satisfied: ffmpy in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (2.0.1)
# Requirement already satisfied: groovy~=0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (1.2.3)
# Requirement already satisfied: jinja2<4.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (3.1.5)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (3.11.5)
# Requirement already satisfied: packaging in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<=2.12.4,>=2.11.10 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (2.12.4)
# Requirement already satisfied: pydub in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio-client==2.0.1->gradio) (2025.10.0)
# Requirement already satisfied: idna>=2.8 in c:\users\dell\appdata\roaming\python\python312\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\users\dell\appdata\roaming\python\python312\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\appdata\roaming\python\python312\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dell\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\dell\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\dell\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\dell\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from torch) (3.5)
# Requirement already satisfied: setuptools in c:\users\dell\appdata\roaming\python\python312\site-packages (from torch) (75.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python312\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import torch
import torch.nn as nn
import numpy as np
import gradio as gr
from torchvision import transforms

# %%
import torch
import torch.nn as nn

class CSRNet(nn.Module):
    def __init__(self):
        super(CSRNet, self).__init__()

        self.frontend = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, 3, padding=1), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 512, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1), nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1), nn.ReLU(inplace=True)
        )

        self.backend = nn.Sequential(
            nn.Conv2d(512, 512, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(512, 256, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, 3, dilation=2, padding=2), nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, 3, dilation=2, padding=2), nn.ReLU(inplace=True)
        )

        # Must match training exactly
        self.output = nn.Conv2d(64, 1, 1)

    def forward(self, x):
        x = self.frontend(x)
        x = self.backend(x)
        x = self.output(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CSRNet().to(device)
model.load_state_dict(torch.load("csrnet_finalb.pth", map_location=device))
model.eval()
# Out:
# CSRNet(
#   (frontend): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#   )
#   (backend): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (3): ReLU(inplace=True)
#     (4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (5): ReLU(inplace=True)
#     (6): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (11): ReLU(inplace=True)
#   )
#   (output): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
def process_frame(frame, threshold=25, show_heatmap=False):
    # Resize for Part B
    frame_resized = cv2.resize(frame, (512, 512))
    img_rgb = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2RGB)

    input_tensor = transform(img_rgb).unsqueeze(0).to(device)

    with torch.no_grad():
        density_map = model(input_tensor)

    count = density_map.sum().item()

    alert = "NORMAL"
    if count > threshold:
        alert = "⚠️ CROWD LIMIT EXCEEDED"

    # Optional heatmap
    if show_heatmap:
        dm = density_map.squeeze().cpu().numpy()
        dm = cv2.normalize(dm, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
        heatmap = cv2.applyColorMap(dm, cv2.COLORMAP_JET)
        heatmap = cv2.resize(heatmap, frame.shape[1::-1])
        overlay = cv2.addWeighted(frame, 0.6, heatmap, 0.4, 0)
    else:
        overlay = frame

    return overlay, f"Count: {int(count)}", alert

# %%
def webcam_stream(threshold, show_heatmap):
    cap = cv2.VideoCapture(0)

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        output, count_text, alert = process_frame(
            frame, threshold, show_heatmap
        )

        yield output, count_text, alert

    cap.release()

# %%
interface = gr.Interface(
    fn=webcam_stream,
    inputs=[
        gr.Slider(1, 100, value=25, label="Crowd Threshold"),
        gr.Checkbox(label="Show Density Heatmap")
    ],
    outputs=[
        gr.Image(type="numpy", label="Live Feed"),
        gr.Textbox(label="Crowd Count"),
        gr.Textbox(label="Alert Status")
    ],
    live=True
)

# %%
interface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 interface.launch()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\gradio\blocks.py:2767, in Blocks.launch(self, inline, inbrowser, share, debug, max_threads, auth, auth_message, prevent_thread_lock, show_error, server_name, server_port, height, width, favicon_path, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_verify, quiet, footer_links, allowed_paths, blocked_paths, root_path, app_kwargs, state_session_capacity, share_server_address, share_server_protocol, share_server_tls_certificate, auth_dependency, max_file_size, enable_monitoring, strict_cors, node_server_name, node_port, ssr_mode, pwa, mcp_server, _frontend, i18n, theme, css, css_paths, js, head, head_paths)
#    2764 # If running in a colab or not able to access localhost,
#    2765 # a shareable link must be created.
#    2766 if _frontend and not networking.url_ok(self.local_url) and not self.share:
# -> 2767     raise ValueError(
#    2768         "When localhost is not accessible, a shareable link must be created. Please set share=True or check your proxy settings to allow access to localhost."
#    2769     )
#    2771 if self.is_colab and not quiet:
#    2772     if debug:
#
# ValueError: When localhost is not accessible, a shareable link must be created. Please set share=True or check your proxy settings to allow access to localhost.
