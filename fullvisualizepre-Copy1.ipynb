# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_1.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_1.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_2.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_2.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_3.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_3.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_4.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_4.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_5.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_5.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_6.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_6.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_7.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_7.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_8.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_8.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_9.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_9.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_10.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_10.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_11.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_11.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_12.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_12.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_13.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_13.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_14.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_14.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_15.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_15.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_16.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_16.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_17.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_17.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_18.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_18.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_19.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_19.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_20.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_20.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_20.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_20.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_21.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_21.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_22.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_22.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_23.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_23.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_24.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_24.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_25.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_25.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_26.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_26.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_27.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_27.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_28.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_28.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_29.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_29.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_30.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_30.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_31.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_31.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_32.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_32.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_33.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_33.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_34.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_34.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_35.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_35.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_36.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_36.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_37.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_37.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_38.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_38.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_39.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_39.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_40.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_40.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_41.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_41.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_42.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_42.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_43.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_43.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_44.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_44.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_45.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_45.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_46.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_46.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_47.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_47.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_48.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_48.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_49.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_49.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_50.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_50.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_51.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_51.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_52.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_52.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_53.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_53.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_54.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_54.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_55.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_55.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_56.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_56.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_57.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_57.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_58.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_58.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_59.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_59.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_60.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_60.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_61.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_61.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_62.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_62.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_63.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_63.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_64.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_64.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_65.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_65.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_66.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_66.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_67.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_67.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_68.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_68.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_69.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_69.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_70.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_70.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_81.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_81.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_82.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_82.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_83.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_83.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_84.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_84.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_85.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_85.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_86.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_86.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_87.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_87.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_88.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_88.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_89.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_89.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_90.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_90.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_91.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_91.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_92.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_92.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_93.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_93.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_94.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_94.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_95.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_95.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_96.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_96.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_97.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_97.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_98.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_98.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_99.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_99.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_100.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_100.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_101.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_101.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_102.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_102.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_103.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_103.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_104.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_104.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_105.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_105.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_106.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_106.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_107.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_107.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_108.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_108.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_109.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_109.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_110.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_110.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_111.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_111.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_112.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_112.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_113.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_113.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_114.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_114.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_115.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_115.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_116.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_116.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_117.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_117.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_118.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_118.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_119.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_119.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_120.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_120.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_121.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_121.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_122.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_122.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_123.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_123.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_124.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_124.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_125.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_125.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_126.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_126.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_127.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_127.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_128.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_128.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_129.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_129.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_130.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_130.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_131.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_131.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_132.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_132.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_133.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_133.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_134.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_134.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_135.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_135.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_136.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_136.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_137.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_137.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_138.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_138.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_139.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_139.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_140.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_140.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_141.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_141.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_142.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_142.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_143.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_143.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_144.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_144.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_145.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_145.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_146.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_146.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_147.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_147.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_148.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_148.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_149.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_149.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_150.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_150.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_151.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_151.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_152.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_152.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_153.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_153.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_154.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_154.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_155.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_155.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_156.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_156.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_157.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_157.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_158.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_158.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_159.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_159.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_160.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_160.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_161.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_161.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_162.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_162.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_163.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_163.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_164.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_164.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_165.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_165.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_166.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_166.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_167.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_167.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_168.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_168.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_169.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_169.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_170.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_170.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_171.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_171.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_172.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_172.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_173.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_173.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_175.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_175.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_176.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_176.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_177.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_177.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_178.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_178.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_179.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_179.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_180.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_180.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_181.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_181.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)

# %%
import cv2
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

img_path = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/images/IMG_182.jpg"
gt_path  = r"C:/Users/Lenovo/Downloads/deep dataset/part_A_final/test_data/ground_truth/GT_IMG_182.mat"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

gt = scipy.io.loadmat(gt_path)
points_raw = gt["image_info"][0][0][0][0][0]

orig_h, orig_w = 768, 1024
scale_w = w / orig_w
scale_h = h / orig_h

points = []
for (x, y) in points_raw:
    points.append([int(x * scale_w), int(y * scale_h)])
points = np.array(points)
count = len(points)

density = np.zeros((h, w), dtype=np.float32)
for (x, y) in points:
    if 0 <= x < w and 0 <= y < h:
        density[int(y), int(x)] = 1

density_map = gaussian_filter(density, sigma=15)

img_points = img.copy()
for (x, y) in points:
    cv2.circle(img_points, (x, y), 4, (255, 0, 0), -1)

density_norm = (density_map / density_map.max() * 255).astype(np.uint8)
heatmap = cv2.applyColorMap(density_norm, cv2.COLORMAP_JET)
overlay = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original Image")

plt.subplot(2,2,2)
plt.imshow(img_points)
plt.title("Points on Image")

plt.subplot(2,2,3)
plt.imshow(density_map, cmap='jet')
plt.title("Density Map")

plt.subplot(2,2,4)
plt.imshow(overlay)
plt.title("Heatmap Overlay")

plt.show()

print("People Count:", count)
